# %%
def main():
    
    import math
    k = float(input("What is the spring constnt on the oscillator")) # defines all relevent variables through user input
    m = float(input("what is the mass of the oscillator"))
    w0 = math.sqrt((k/m))
    b = float(input("What is the coefficient of viscous friction"))
    y = (b/m)
    x0 = float(input("How far back was the oscilator pulled?"))
    w1 = math.sqrt(w0**2 - (y/2)**2)
    f = float(input("What is the driving force of the oscilator?"))
    w = float(input("What is the frequency of the driving force?"))
    X = (f/m)/(math.sqrt((w0**2 - w**2)**2 + (w*y)**2))
    phi = math.atan((y*0.5)/(w0**2 - w**2))
    
    t=0 # creates a time lapse which will also be used as a recursive smaple method
    while t < 10:
        
        if f != 0: #defines the driven oscillator case
            position = (f/((2*m*w0*((w0 - w)**2) + ((y/2))**2)**(1/2)))*math.cos(wt)
            energy = 0.5*k*(position/(math.cos(wt)))**2
            PE = 0.5*k*(position)**2
            KE = energy - PE
            t = t + 0.5
            print (position)
            print (energy)
            print (PE)
            print (KE)
        
        if b ==0 and f == 0: #defines the standard ideal case
            position = x0*math.cos(w0*t)
            energy = 0.5*k*(x0)**2
            PE = 0.5*k*(position)**2
            KE = energy - PE         
            t = t + 0.5
            print (position)
            print (energy)
            print (PE)
            print (KE)
        
        if b != 0 and f == 0: # defines the dampened oscillator case
            position = X0*cos(w0*t)*e^((-yt)/2)
            energy = 0.5*k*((x0)^(2))*e^(-yt)
            PE = energy*(cos(w0t))^2
            KE = energy - PE
            print (position)
            print (energy)
            print (KE)
            print (PE)
            t = t + 0.5
            
        
main ()
# Out:
# What is the spring constnt on the oscillator4
# what is the mass of the oscillator110
# What is the coefficient of viscous friction0
# How far back was the oscilator pulled?6
# What is the driving force of the oscilator?0
# What is the frequency of the driving force?0
# 6.0
# 72.0
# 72.0
# 0.0
# 5.972747927624357
# 72.0
# 71.3474356138821
# 0.652564386117902
# 5.8912392689803506
# 72.0
# 69.41340024875227
# 2.586599751247732
# 5.756214450689518
# 72.0
# 66.26800960465366
# 5.731990395346344
# 5.568900041458713
# 72.0
# 62.02529534351771
# 9.974704656482288
# 5.3309976099003915
# 72.0
# 56.839071033527375
# 15.160928966472625
# 5.044668267442274
# 72.0
# 50.897355857078075
# 21.102644142921925
# 4.71251303673901
# 72.0
# 44.41555824287024
# 27.58444175712976
# 4.33754922391962
# 72.0
# 37.628666539851395
# 34.371333460148605
# 3.92318300930584
# 72.0
# 30.782729849012053
# 41.21727015098794
# 3.473178505587896
# 72.0
# 24.12593786335554
# 47.87406213664446
# 2.991623564534015
# 72.0
# ...
